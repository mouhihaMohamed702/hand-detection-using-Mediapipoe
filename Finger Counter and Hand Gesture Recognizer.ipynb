# %% [markdown]
# # **<center><font style="color:rgb(100,109,254)">Real-Time Fingers Counter & Hand Gesture Recognizer with Mediapipe and Python</font> </center>**
#
#
#
#
# ## **<font style="color:rgb(134,19,348)"> Outline </font>**
#
# - ***`Step 1:`*Perform Hands Landmarks Detection**
#
# - ***`Step 2:`*Build the Fingers Counter**
#
# - ***`Step 3:`*Visualize the Counted Fingers**
#
# - ***`Step 4:`*Build the Hand Gesture Recognizer**
#
# - ***`Step 5:`*Build a Selfie-Capturing System controlled by Hand Gestures**
#
# Alright, so without further ado, let's get started.

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)"> Import the Libraries</font>**
#
# First, we will import the required libraries.

# %%
import cv2
import time
import pygame
import numpy as np
import mediapipe as mp
import matplotlib.pyplot as plt
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.10.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Initialize the Hands Landmarks Detection Model</font>**

# %%
# Initialize the mediapipe hands class.
mp_hands = mp.solutions.hands

# Set up the Hands functions for images and videos.
# Set up the Hands functions for images and videos.
# static_image_mode=True redetect every image input => lent but if it false  detect in the same way
# max_num_hands=2 the number of hunds
# min_detection_confidence=0.5 when the confidence is few and the model detect without problems so our algo is good
hands = mp_hands.Hands(static_image_mode=True, max_num_hands=2, min_detection_confidence=0.5)
hands_videos = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5)

# Initialize the mediapipe drawing class.
mp_drawing = mp.solutions.drawing_utils

# %% [markdown]
# ## **<font style="color:rgb(134,19,348)">Step 1: Perform Hands Landmarks Detection</font>**

# %%
def detectHandsLandmarks(image, hands, draw=True, display = True):
    '''
    This function performs hands landmarks detection on an image.
    Args:
        image:   The input image with prominent hand(s) whose landmarks needs to be detected.
        hands:   The Hands function required to perform the hands landmarks detection.
        draw:    A boolean value that is if set to true the function draws hands landmarks on the output image. 
        display: A boolean value that is if set to true the function displays the original input image, and the output 
                 image with hands landmarks drawn if it was specified and returns nothing.
    Returns:
        output_image: A copy of input image with the detected hands landmarks drawn if it was specified.
        results:      The output of the hands landmarks detection on the input image.
    '''
    
    # Create a copy of the input image to draw landmarks on.
    output_image = image.copy()
    
    # Convert the image from BGR into RGB format.
    imgRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Perform the Hands Landmarks Detection.
    results = hands.process(imgRGB)
    print(results.multi_handedness)
    # Check if landmarks are found and are specified to be drawn.
    if results.multi_hand_landmarks and draw:
        
        # Iterate over the found hands.
        for hand_landmarks in results.multi_hand_landmarks:
            
            # Draw the hand landmarks on the copy of the input image.
            mp_drawing.draw_landmarks(image = output_image, landmark_list = hand_landmarks,
                                      connections = mp_hands.HAND_CONNECTIONS,
                                      landmark_drawing_spec=mp_drawing.DrawingSpec(color=(255,255,255),
                                                                                   thickness=2, circle_radius=2),
                                      connection_drawing_spec=mp_drawing.DrawingSpec(color=(0,255,0),
                                                                                     thickness=2, circle_radius=2))
    
    # Check if the original input image and the output image are specified to be displayed.
    if display:
        
        # Display the original input image and the output image.
        plt.figure(figsize=[15,15])
        plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image");plt.axis('off');
        plt.subplot(122);plt.imshow(output_image[:,:,::-1]);plt.title("Output");plt.axis('off');
        
    # Otherwise
    else:
        
        # Return the output image and results of hands landmarks detection.
        return output_image, results

# %% [markdown]
# Now let's test the function **`detectHandsLandmarks()`** created above to perform hands landmarks detection on a sample image and display the results.

# %%
# Read a sample image and perform hands landmarks detection on it.
image = cv2.imread('media/anapc.jpg')
detectHandsLandmarks(image, hands, display=True)
# Out:
# [classification {
#   index: 1
#   score: 0.9879245758056641
#   label: "Right"
# }
# , classification {
#   index: 0
#   score: 0.9589903354644775
#   label: "Left"
# }
# ]

# %%
def countFingers(image, results, draw=True, display=True):
    '''
    This function will count the number of fingers up for each hand in the image.
    Args:
        image:   The image of the hands on which the fingers counting is required to be performed.
        results: The output of the hands landmarks detection performed on the image of the hands.
        draw:    A boolean value that is if set to true the function writes the total count of fingers of the hands on the
                 output image.
        display: A boolean value that is if set to true the function displays the resultant image and returns nothing.
    Returns:
        output_image:     A copy of the input image with the fingers count written, if it was specified.
        fingers_statuses: A dictionary containing the status (i.e., open or close) of each finger of both hands.
        count:            A dictionary containing the count of the fingers that are up, of both hands.
    '''
    
    # Get the height and width of the input image.
    height, width, _ = image.shape
    
    # Create a copy of the input image to write the count of fingers on.
    output_image = image.copy()
    
    # Initialize a dictionary to store the count of fingers of both hands.
    count = {'RIGHT': 0, 'LEFT': 0}
    
    # Store the indexes of the tips landmarks of each finger of a hand in a list.
    fingers_tips_ids = [mp_hands.HandLandmark.INDEX_FINGER_TIP, mp_hands.HandLandmark.MIDDLE_FINGER_TIP,
                        mp_hands.HandLandmark.RING_FINGER_TIP, mp_hands.HandLandmark.PINKY_TIP]
    
    # Initialize a dictionary to store the status (i.e., True for open and False for close) of each finger of both hands.
    fingers_statuses = {'RIGHT_THUMB': False, 'RIGHT_INDEX': False, 'RIGHT_MIDDLE': False, 'RIGHT_RING': False,
                        'RIGHT_PINKY': False, 'LEFT_THUMB': False, 'LEFT_INDEX': False, 'LEFT_MIDDLE': False,
                        'LEFT_RING': False, 'LEFT_PINKY': False}
    
    
    # Iterate over the found hands in the image.
    for hand_index, hand_info in enumerate(results.multi_handedness):
        
        # Retrieve the label of the found hand.
        hand_label = hand_info.classification[0].label
        
        # Retrieve the landmarks of the found hand.
        hand_landmarks =  results.multi_hand_landmarks[hand_index]
        
        # Iterate over the indexes of the tips landmarks of each finger of the hand.
        for tip_index in fingers_tips_ids:
            
            # Retrieve the label (i.e., index, middle, etc.) of the finger on which we are iterating upon.
            finger_name = tip_index.name.split("_")[0]
            
            # Check if the finger is up by comparing the y-coordinates of the tip and pip landmarks.
            if (hand_landmarks.landmark[tip_index].y < hand_landmarks.landmark[tip_index - 2].y):
                
                # Update the status of the finger in the dictionary to true.
                fingers_statuses[hand_label.upper()+"_"+finger_name] = True
                
                # Increment the count of the fingers up of the hand by 1.
                count[hand_label.upper()] += 1
        
        # Retrieve the y-coordinates of the tip and mcp landmarks of the thumb of the hand.
        thumb_tip_x = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].x
        thumb_mcp_x = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP - 2].x
        
        # Check if the thumb is up by comparing the hand label and the x-coordinates of the retrieved landmarks.
        if (hand_label=='Right' and (thumb_tip_x < thumb_mcp_x)) or (hand_label=='Left' and (thumb_tip_x > thumb_mcp_x)):
            
            # Update the status of the thumb in the dictionary to true.
            fingers_statuses[hand_label.upper()+"_THUMB"] = True
            
            # Increment the count of the fingers up of the hand by 1.
            count[hand_label.upper()] += 1
     
    # Check if the total count of the fingers of both hands are specified to be written on the output image.
    if draw:

        # Write the total count of the fingers of both hands on the output image.
        cv2.putText(output_image, " Total Fingers: ", (10, 25),cv2.FONT_HERSHEY_COMPLEX, 1, (20,255,155), 2)
        cv2.putText(output_image, str(sum(count.values())), (width//2-150,240), cv2.FONT_HERSHEY_SIMPLEX,
                    8.9, (20,255,155), 10, 10)

    # Check if the output image is specified to be displayed.
    if display:
        
        # Display the output image.
        plt.figure(figsize=[10,10])
        plt.imshow(output_image[:,:,::-1]);plt.title("Output Image");plt.axis('off');
    
    # Otherwise
    else:

        # Return the output image, the status of each finger and the count of the fingers up of both hands.
        return output_image, fingers_statuses, count

# %% [markdown]
# ## first version

# %%
# Initialize the VideoCapture object to read from the webcam.
camera_video = cv2.VideoCapture(0)
camera_video.set(3,1280)
camera_video.set(4,960)

# Create named window for resizing purposes.
cv2.namedWindow('Fingers Counter', cv2.WINDOW_NORMAL)

# Iterate until the webcam is accessed successfully.
while camera_video.isOpened():
    
    # Read a frame.
    ok, frame = camera_video.read()
    
    # Check if frame is not read properly then continue to the next iteration to read the next frame.
    if not ok:
        continue
    
    # Flip the frame horizontally for natural (selfie-view) visualization.
    frame = cv2.flip(frame, 1)
    
    # Perform Hands landmarks detection on the frame.
    frame, results = detectHandsLandmarks(frame, hands_videos, display=False)
    
    # Check if the hands landmarks in the frame are detected.
    if results.multi_hand_landmarks:
            
        # Count the number of fingers up of each hand in the frame.
        frame, fingers_statuses, count = countFingers(frame, results, display=False)
                
    # Display the frame.
    cv2.imshow('Fingers Counter', frame)
    
    # Wait for 1ms. If a key is pressed, retreive the ASCII code of the key.
    k = cv2.waitKey(1) & 0xFF
    
    # Check if 'ESC' is pressed and break the loop.
    if(k == 27):
        break

# Release the VideoCapture Object and close the windows.
camera_video.release()
cv2.destroyAllWindows()
# Out:
# [classification {
#   index: 0
#   score: 0.9825654029846191
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9870847463607788
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9853078722953796
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9948709011077881
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9973763227462769
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9967495799064636
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.994534432888031
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9931143522262573
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9970858693122864
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9742164611816406
#   label: "Left"
# }
# , classification {
#   index: 0
#   score: 0.9978035092353821
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9885369539260864
#   label: "Left"
# }
# , classification {
#   index: 0
#   score: 0.9972096085548401
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9957850575447083
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9927651286125183
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9927728772163391
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9856463670730591
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9802567362785339
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9871906042098999
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9884756803512573
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.995464026927948
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9915242195129395
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.988738477230072
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9884589910507202
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9987524151802063
#   label: "Left"
# }
# , classification {
#   index: 0
#   score: 0.9956980347633362
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9945228099822998
#   label: "Left"
# }
# ]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [classification {
#   index: 0
#   score: 0.9593235850334167
#   label: "Left"
# }
# ]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [classification {
#   index: 1
#   score: 0.8608729839324951
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9088395833969116
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.6109733581542969
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9512047171592712
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.6236140727996826
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9551486372947693
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.8548200726509094
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9414353966712952
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9382535219192505
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9442394375801086
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9588655233383179
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9444119334220886
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9584454894065857
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9518023729324341
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9552451968193054
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9542669653892517
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9592929482460022
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9557051658630371
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9644982218742371
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9680017232894897
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9701628684997559
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9591521620750427
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9541012048721313
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.965783417224884
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9596988558769226
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9674673676490784
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9669348001480103
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9693953990936279
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9620081186294556
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9720436334609985
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9504521489143372
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9299854636192322
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9537556171417236
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9300228357315063
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9440440535545349
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9052516222000122
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.920178234577179
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9370836615562439
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9256981015205383
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9251441955566406
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9168378114700317
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9378812909126282
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.931108295917511
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9141185283660889
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9347126483917236
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9217313528060913
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9328663349151611
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9276005029678345
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9255845546722412
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9167101383209229
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9320952892303467
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9239870309829712
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9280393123626709
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9393006563186646
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9238490462303162
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9151415824890137
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.92542564868927
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9301451444625854
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9266675710678101
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9399457573890686
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9250087141990662
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9321550726890564
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9210637807846069
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9277874231338501
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9176668524742126
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9325003027915955
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9216984510421753
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9058299660682678
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9189159274101257
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9087969064712524
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9211739301681519
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9344525337219238
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9397910237312317
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9409709572792053
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9508395195007324
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9453728199005127
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.933139443397522
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9516339302062988
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9878880977630615
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9914641380310059
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9888420104980469
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9888826608657837
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9876774549484253
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.990399956703186
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9886766672134399
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9910926222801208
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9904836416244507
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9923690557479858
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9920992851257324
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9923653602600098
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9908880591392517
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.992106556892395
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9909905791282654
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9911453127861023
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9922016859054565
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9914349913597107
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.990064263343811
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.988955557346344
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.992207944393158
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9922891855239868
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9926248788833618
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9882049560546875
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9903873801231384
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9909147620201111
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9924079179763794
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9891425371170044
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9916213154792786
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9919105172157288
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9907750487327576
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9899455904960632
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9899168014526367
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9901058673858643
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.990730881690979
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9910381436347961
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9874359369277954
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.988990068435669
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9909836053848267
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9883280396461487
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9916455745697021
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.989578127861023
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9883145093917847
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9918935298919678
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9898172616958618
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9937024712562561
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9945986866950989
#   label: "Right"
# }
# ]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
def annotate(image, results, fingers_statuses, count, display=True):
    '''
    This function will draw an appealing visualization of each fingers up of the both hands in the image.
    Args:
        image:            The image of the hands on which the counted fingers are required to be visualized.
        results:          The output of the hands landmarks detection performed on the image of the hands.
        fingers_statuses: A dictionary containing the status (i.e., open or close) of each finger of both hands. 
        count:            A dictionary containing the count of the fingers that are up, of both hands.
        display:          A boolean value that is if set to true the function displays the resultant image and 
                          returns nothing.
    Returns:
        output_image: A copy of the input image with the visualization of counted fingers.
    '''
    
    # Get the height and width of the input image.
    height, width, _ = image.shape
    
    # Create a copy of the input image.
    output_image = image.copy()
    
    # Select the images of the hands prints that are required to be overlayed.
    ########################################################################################################################

    # Initialize a dictionaty to store the images paths of the both hands.
    # Initially it contains red hands images paths. The red image represents that the hand is not present in the image. 
    HANDS_IMGS_PATHS = {'LEFT': ['media/left_hand_not_detected.png'], 'RIGHT': ['media/right_hand_not_detected.png']}
    
    # Check if there is hand(s) in the image.
    if results.multi_hand_landmarks:
        
        # Iterate over the detected hands in the image.
        for hand_index, hand_info in enumerate(results.multi_handedness):
            
            # Retrieve the label of the hand.
            hand_label = hand_info.classification[0].label
            
            # Update the image path of the hand to a green color hand image.
            # This green image represents that the hand is present in the image. 
            HANDS_IMGS_PATHS[hand_label.upper()] = ['media/'+hand_label.lower()+'_hand_detected.png']
            
            # Check if all the fingers of the hand are up/open.
            if count[hand_label.upper()] == 5:
                
                # Update the image path of the hand to a hand image with green color palm and orange color fingers image.
                # The orange color of a finger represents that the finger is up.
                HANDS_IMGS_PATHS[hand_label.upper()] = ['media/'+hand_label.lower()+'_all_fingers.png']
            
            # Otherwise if all the fingers of the hand are not up/open.
            else:
                
                # Iterate over the fingers statuses of the hands.
                for finger, status in fingers_statuses.items():
                    
                    # Check if the finger is up and belongs to the hand that we are iterating upon.
                    if status == True and finger.split("_")[0] == hand_label.upper():
                        
                        # Append another image of the hand in the list inside the dictionary.
                        # This image only contains the finger we are iterating upon of the hand in orange color.
                        # As the orange color represents that the finger is up.
                        HANDS_IMGS_PATHS[hand_label.upper()].append('media/'+finger.lower()+'.png')
    
    ########################################################################################################################
    
    # Overlay the selected hands prints on the input image.
    ########################################################################################################################
    
    # Iterate over the left and right hand.
    for hand_index, hand_imgs_paths in enumerate(HANDS_IMGS_PATHS.values()):
        
        # Iterate over the images paths of the hand.
        for img_path in hand_imgs_paths:
            
            # Read the image including its alpha channel. The alpha channel (0-255) determine the level of visibility. 
            # In alpha channel, 0 represents the transparent area and 255 represents the visible area.
            hand_imageBGRA = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
            
            # Retrieve all the alpha channel values of the hand image. 
            alpha_channel = hand_imageBGRA[:,:,-1]
            
            # Retrieve all the blue, green, and red channels values of the hand image.
            # As we also need the three-channel version of the hand image. 
            hand_imageBGR  = hand_imageBGRA[:,:,:-1]
            
            # Retrieve the height and width of the hand image.
            hand_height, hand_width, _ = hand_imageBGR.shape

            # Retrieve the region of interest of the output image where the handprint image will be placed.
            ROI = output_image[30 : 30 + hand_height,
                               (hand_index * width//2) + width//12 : ((hand_index * width//2) + width//12 + hand_width)]
            
            # Overlay the handprint image by updating the pixel values of the ROI of the output image at the 
            # indexes where the alpha channel has the value 255.
            ROI[alpha_channel==255] = hand_imageBGR[alpha_channel==255]

            # Update the ROI of the output image with resultant image pixel values after overlaying the handprint.
            output_image[30 : 30 + hand_height,
                         (hand_index * width//2) + width//12 : ((hand_index * width//2) + width//12 + hand_width)] = ROI
    
    ########################################################################################################################

    # Check if the output image is specified to be displayed.
    if display:

        # Display the output image.
        plt.figure(figsize=[10,10])
        plt.imshow(output_image[:,:,::-1]);plt.title("Output Image");plt.axis('off');
    
    # Otherwise
    else:

        # Return the output image
        return output_image

# %%
# Initialize the VideoCapture object to read from the webcam.
camera_video = cv2.VideoCapture(0)
camera_video.set(3,1280)
camera_video.set(4,960)

# Create named window for resizing purposes.
cv2.namedWindow('Counted Fingers Visualization', cv2.WINDOW_NORMAL)

# Iterate until the webcam is accessed successfully.
while camera_video.isOpened():
    
    # Read a frame.
    ok, frame = camera_video.read()
    
    # Check if frame is not read properly then continue to the next iteration to read the next frame.
    if not ok:
        continue
    
    # Flip the frame horizontally for natural (selfie-view) visualization.
    frame = cv2.flip(frame, 1)
    
    # Perform Hands landmarks detection on the frame.
    frame, results = detectHandsLandmarks(frame, hands_videos, display=False)
    
    # Check if the hands landmarks in the frame are detected.
    if results.multi_hand_landmarks:
            
        # Count the number of fingers up of each hand in the frame.
        frame, fingers_statuses, count = countFingers(frame, results, display=False)
    
    # Visualize the counted fingers.
    frame = annotate(frame, results, fingers_statuses, count, display=False)
                
    # Display the frame.
    cv2.imshow('Counted Fingers Visualization', frame)
    
    # Wait for 1ms. If a key is pressed, retreive the ASCII code of the key.
    k = cv2.waitKey(1) & 0xFF
    
    # Check if 'ESC' is pressed and break the loop.
    if(k == 27):
        break

# Release the VideoCapture Object and close the windows.
camera_video.release()
cv2.destroyAllWindows()
# Out:
# None
# None
# None
# None
# [classification {
#   index: 1
#   score: 0.9861297011375427
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9969193935394287
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9919543266296387
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9875034093856812
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9933119416236877
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9930211901664734
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9923035502433777
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9907262325286865
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9918816089630127
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9976592659950256
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9973317384719849
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9313600063323975
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.7254633903503418
#   label: "Right"
# }
# ]
# None
# None
# [classification {
#   index: 0
#   score: 0.9402680993080139
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9866735935211182
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9949154257774353
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9931294918060303
#   label: "Left"
# }
# ]
# [classification {
#   index: 0
#   score: 0.9518516063690186
#   label: "Left"
# }
# ]
# None
# None
# None
# [classification {
#   index: 1
#   score: 0.9969307780265808
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.99964839220047
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9970659017562866
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9970892071723938
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9966791272163391
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9912348389625549
#   label: "Right"
# }
# ]
# None
# None
# None
# None
# None
# [classification {
#   index: 1
#   score: 0.9980430006980896
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9981472492218018
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9969406723976135
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9993840456008911
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9996621012687683
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9993428587913513
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9996736645698547
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.99985671043396
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9993650913238525
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.999845027923584
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9994930028915405
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.995406985282898
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9947245717048645
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9947314858436584
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9864102005958557
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9989299774169922
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9821574091911316
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9787210822105408
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.998078465461731
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9781389236450195
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9979504346847534
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9839622974395752
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9714816212654114
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9972414970397949
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9771478772163391
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9947039484977722
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9771384000778198
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.978649914264679
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9862821102142334
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9861705303192139
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9825539588928223
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9890864491462708
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9801968336105347
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9782888889312744
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.985243022441864
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9823024272918701
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9859824776649475
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9642285108566284
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9744306206703186
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.975581169128418
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9830514192581177
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9841803312301636
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9774119853973389
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9826824069023132
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9635211825370789
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.98316490650177
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9842400550842285
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9695711135864258
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9795461297035217
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9417584538459778
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.943007230758667
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8628044128417969
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9164735078811646
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8726305961608887
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9272227883338928
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.961778461933136
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9534600377082825
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9535846710205078
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9260789155960083
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9230244755744934
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9369751811027527
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.928460419178009
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9193891286849976
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9456615447998047
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9503863453865051
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9410659670829773
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9397911429405212
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9598079323768616
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9271731972694397
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9494248628616333
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9397147297859192
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9510673880577087
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9421643614768982
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9437563419342041
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8964874148368835
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9018877148628235
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.901570200920105
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8912322521209717
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9229152202606201
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9722347855567932
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9876978397369385
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9805077910423279
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9849002957344055
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9878197312355042
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9758445620536804
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9820243120193481
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9836860299110413
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9884007573127747
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.91610187292099
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9080666303634644
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9352685213088989
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.92023766040802
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.892629086971283
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8877221941947937
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8078687787055969
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8530755639076233
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8318265676498413
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8978123068809509
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8604286909103394
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8042781352996826
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8328229188919067
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8400648832321167
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8601727485656738
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8452829122543335
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8696106672286987
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8049773573875427
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8390589952468872
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.8824777007102966
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9352385997772217
#   label: "Right"
# }
# ]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# Woah! that was Cool, the results are delightful.
#
# ## **<font style="color:rgb(134,19,348)">Step 4: Build the Hand Gesture Recognizer</font>**
#
#
#
# * **V Hand Gesture** ✌️ ( only the index and middle finger up)
# * **SPIDERMAN Hand Gesture** 🤟 (the thumb, index, and pinky finger up)
# * **HIGH-FIVE Hand Gesture** ✋ ( all the five fingers up)

# %%
def recognizeGestures(image, fingers_statuses, count, draw=True, display=True):
    '''
    This function will determine the gesture of the left and right hand in the image.
    Args:
        image:            The image of the hands on which the hand gesture recognition is required to be performed.
        fingers_statuses: A dictionary containing the status (i.e., open or close) of each finger of both hands. 
        count:            A dictionary containing the count of the fingers that are up, of both hands.
        draw:             A boolean value that is if set to true the function writes the gestures of the hands on the
                          output image, after recognition.
        display:          A boolean value that is if set to true the function displays the resultant image and 
                          returns nothing.
    Returns:
        output_image:   A copy of the input image with the left and right hand recognized gestures written if it was 
                        specified.
        hands_gestures: A dictionary containing the recognized gestures of the right and left hand.
    '''
    
    # Create a copy of the input image.
    output_image = image.copy()
    
    # Store the labels of both hands in a list.
    hands_labels = ['RIGHT', 'LEFT']
    
    # Initialize a dictionary to store the gestures of both hands in the image.
    hands_gestures = {'RIGHT': "UNKNOWN", 'LEFT': "UNKNOWN"}
    
    # Iterate over the left and right hand.
    for hand_index, hand_label in enumerate(hands_labels):
        
        # Initialize a variable to store the color we will use to write the hands gestures on the image.
        # Initially it is red which represents that the gesture is not recognized.
        color = (0, 0, 255)
        
        # Check if the person is making the 'V' gesture with the hand.
        ####################################################################################################################
        
        # Check if the number of fingers up is 2 and the fingers that are up, are the index and the middle finger.
        if count[hand_label] == 2  and fingers_statuses[hand_label+'_MIDDLE'] and fingers_statuses[hand_label+'_INDEX']:
            
            # Update the gesture value of the hand that we are iterating upon to V SIGN.
            hands_gestures[hand_label] = "V SIGN"
            
            # Update the color value to green.
            color=(0,255,0)
            
        ####################################################################################################################            
        
        # Check if the person is making the 'SPIDERMAN' gesture with the hand.
        ##########################################################################################################################################################
        
        # Check if the number of fingers up is 3 and the fingers that are up, are the thumb, index and the pinky finger.
        elif count[hand_label] == 3 and fingers_statuses[hand_label+'_THUMB'] and fingers_statuses[hand_label+'_INDEX'] and fingers_statuses[hand_label+'_PINKY']:
                
            # Update the gesture value of the hand that we are iterating upon to SPIDERMAN SIGN.
            hands_gestures[hand_label] = "happy signe"

            # Update the color value to green.
            color=(0,255,0)
                
        ##########################################################################################################################################################
        
        # Check if the person is making the 'HIGH-FIVE' gesture with the hand.
        ####################################################################################################################
        
        # Check if the number of fingers up is 5, which means that all the fingers are up.
        elif count[hand_label] == 5:
            
            # Update the gesture value of the hand that we are iterating upon to HIGH-FIVE SIGN.
            hands_gestures[hand_label] = "HIGH-FIVE SIGN"
            
            # Update the color value to green.
            color=(0,255,0)
       
        ####################################################################################################################  
        
        # Check if the hands gestures are specified to be written.
        if draw:
        
            # Write the hand gesture on the output image. 
            cv2.putText(output_image, hand_label +': '+ hands_gestures[hand_label] , (10, (hand_index+1) * 60),
                        cv2.FONT_HERSHEY_PLAIN, 4, color, 5)
            
    
    # Check if the output image is specified to be displayed.
    if display:

        # Display the output image.
        plt.figure(figsize=[10,10])
        plt.imshow(output_image[:,:,::-1]);plt.title("Output Image");plt.axis('off');
    
    # Otherwise
    else:

        # Return the output image and the gestures of the both hands.
        return output_image, hands_gestures

# %%
# Read a sample image and perform the hand gesture recognition on it after flipping it horizontally.
image = cv2.imread('media/sample1.jpg')
flipped_image = cv2.flip(image, 1)
_, results = detectHandsLandmarks(flipped_image, hands, display=False)
if results.multi_hand_landmarks:
    output_image, fingers_statuses, count = countFingers(image, results, draw=False, display = False)
    recognizeGestures(image, fingers_statuses, count)
# Out:
# [classification {
#   index: 1
#   score: 0.9974375367164612
#   label: "Right"
# }
# ]

# %%
# Read another sample image and perform the hand gesture recognition on it after flipping it horizontally.
image = cv2.imread('media/sample2.jpg')
flipped_image = cv2.flip(image, 1)
_, results = detectHandsLandmarks(flipped_image, hands, display=False)
if results.multi_hand_landmarks:
    output_image, fingers_statuses, count =countFingers(image, results, draw=False, display = False)
    recognizeGestures(image, fingers_statuses, count)
# Out:
# [classification {
#   index: 0
#   score: 0.993830680847168
#   label: "Left"
# }
# , classification {
#   index: 1
#   score: 0.9992042183876038
#   label: "Right"
# }
# ]

# %%
# Read another sample image and perform the hand gesture recognition on it after flipping it horizontally.
image = cv2.imread('media/sample3.jpg')
flipped_image = cv2.flip(image, 1)
_, results = detectHandsLandmarks(flipped_image, hands, display=False)
if results.multi_hand_landmarks:
    output_image, fingers_statuses, count =countFingers(image, results, draw=False, display = False)
    recognizeGestures(image, fingers_statuses, count)
# Out:
# [classification {
#   index: 1
#   score: 0.9658340215682983
#   label: "Right"
# }
# ]

# %% [markdown]
# ## **<font style="color:rgb(134,19,348)">Step 5: Build a Selfie-Capturing System controlled by Hand Gestures</font>**
#
# In

# %%
# Initialize the VideoCapture object to read from the webcam.
camera_video = cv2.VideoCapture(0)
camera_video.set(3,1280)
camera_video.set(4,960)

# Create named window for resizing purposes.
cv2.namedWindow('Selfie-Capturing System', cv2.WINDOW_NORMAL)

# Read the filter image with its blue, green, red, and alpha channel.
filter_imageBGRA = cv2.imread('media/filter.png', cv2.IMREAD_UNCHANGED)

# Initialize a variable to store the status of the filter (i.e., whether to apply the filter or not).
filter_on = False

# Initialize the pygame modules and load the image-capture music file.
pygame.init()
pygame.mixer.music.load("media/cam.mp3")

# Initialize the number of consecutive frames on which we want to check the hand gestures before triggering the events.
num_of_frames = 5

# Initialize a dictionary to store the counts of the consecutive frames with the hand gestures recognized.
counter = {'V SIGN': 0, 'happy signe': 0, 'HIGH-FIVE SIGN': 0}

# Initialize a variable to store the captured image.
captured_image = None

# Iterate until the webcam is accessed successfully.
while camera_video.isOpened():
    
    # Read a frame.
    ok, frame = camera_video.read()
    
    # Check if frame is not read properly then continue to the next iteration to read the next frame.
    if not ok:
        continue
    
    # Flip the frame horizontally for natural (selfie-view) visualization.
    frame = cv2.flip(frame, 1)
    
    # Get the height and width of the frame of the webcam video.
    frame_height, frame_width, _ = frame.shape
    
    # Resize the filter image to the size of the frame.
    filter_imageBGRA = cv2.resize(filter_imageBGRA, (frame_width, frame_height))
    
    # Get the three-channel (BGR) image version of the filter image.
    filter_imageBGR  = filter_imageBGRA[:,:,:-1]
    
    # Perform Hands landmarks detection on the frame.
    frame, results = detectHandsLandmarks(frame, hands_videos, draw=False, display=False)
    
    # Check if the hands landmarks in the frame are detected.
    if results.multi_hand_landmarks:
            
        # Count the number of fingers up of each hand in the frame.
        frame, fingers_statuses, count = countFingers(frame, results, draw=False, display=False)
        
        # Perform the hand gesture recognition on the hands in the frame.
        _, hands_gestures = recognizeGestures(frame, fingers_statuses, count, draw=False, display=False)
        
        
        # Check if the gesture of any hand in the frame is HIGH-FIVE SIGN.
        if any(hand_gesture == "HIGH-FIVE SIGN" for hand_gesture in hands_gestures.values()):
            
            # Increment the count of consecutive frames with HIGH-FIVE hand gesture recognized.
            counter['HIGH-FIVE SIGN'] += 1

            # Check if the counter is equal to the required number of consecutive frames.  
            if counter['HIGH-FIVE SIGN'] == num_of_frames:
            
                # Turn off the filter by updating the value of the filter status variable to False.
                filter_on = False
                
                # Update the counter value to zero.
                counter['HIGH-FIVE SIGN'] = 0
                
        # Otherwise if the gesture of any hand in the frame is not HIGH-FIVE SIGN.
        else:

            # Update the counter value to zero. As we are counting the consective frames with HIGH-FIVE hand gesture.
            counter['HIGH-FIVE SIGN'] = 0
        
        ####################################################################################################################
        
    # Check if the filter is turned on.
    if filter_on:
        
        # Apply the filter by updating the pixel values of the frame at the indexes where the 
        # alpha channel of the filter image has the value 255.
        frame[filter_imageBGRA[:,:,-1]==255] = filter_imageBGR[filter_imageBGRA[:,:,-1]==255]
        
        ####################################################################################################################
    
    # Image Capture Functionality.
    ########################################################################################################################
    
    # Check if the hands landmarks are detected and the gesture of any hand in the frame is V SIGN.
    if results.multi_hand_landmarks and any(hand_gesture == "V SIGN" for hand_gesture in hands_gestures.values()):
        
        # Increment the count of consecutive frames with V hand gesture recognized.
        counter['V SIGN'] += 1
            
        # Check if the counter is equal to the required number of consecutive frames.  
        if counter['V SIGN'] == num_of_frames:
            
            # Make a border around a copy of the current frame.
            captured_image = cv2.copyMakeBorder(src=frame, top=10, bottom=10, left=10, right=10,
                                                borderType=cv2.BORDER_CONSTANT, value=(255,255,255))
            
            # Capture an image and store it in the disk.
            cv2.imwrite('Captured_Image.png', captured_image)
            
            # Display a black image.
            cv2.imshow('Selfie-Capturing System', np.zeros((frame_height, frame_width)))

            # Play the image capture music to indicate the an image is captured and wait for 100 milliseconds.
            pygame.mixer.music.play()
            cv2.waitKey(100)

            # Display the captured image.
            plt.close();plt.figure(figsize=[10,10])
            plt.imshow(frame[:,:,::-1]);plt.title("Captured Image");plt.axis('off');
            
            # Update the counter value to zero.
            counter['V SIGN'] = 0
            
    # Otherwise if the gesture of any hand in the frame is not V SIGN.
    else:
        
        # Update the counter value to zero. As we are counting the consective frames with V hand gesture.
        counter['V SIGN'] = 0
    
    ########################################################################################################################
    
    # Check if we have captured an image.
    if captured_image is not None:
        
        # Resize the image to the 1/5th of its current width while keeping the aspect ratio constant.
        captured_image = cv2.resize(captured_image, (frame_width//5, int(((frame_width//5) / frame_width) * frame_height)))
        
        # Get the new height and width of the image.
        img_height, img_width, _ = captured_image.shape
        
        # Overlay the resized captured image over the frame by updating its pixel values in the region of interest.
        frame[10: 10+img_height, 10: 10+img_width] = captured_image
    
    # Display the frame.
    cv2.imshow('Selfie-Capturing System', frame)
    
    # Wait for 1ms. If a key is pressed, retreive the ASCII code of the key.
    k = cv2.waitKey(1) & 0xFF
    
    # Check if 'ESC' is pressed and break the loop.
    if(k == 27):
        break

# Release the VideoCapture Object and close the windows.
camera_video.release()
cv2.destroyAllWindows()
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [classification {
#   index: 1
#   score: 0.9631569385528564
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9966914653778076
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9923308491706848
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9916625618934631
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9978247880935669
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9883052706718445
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9926838874816895
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9983968138694763
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9932227730751038
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9924448132514954
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9979382753372192
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9923465847969055
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9929147362709045
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9971650838851929
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9930407404899597
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9911530017852783
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9974468350410461
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9884068965911865
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9911662936210632
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.998394250869751
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9902451634407043
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9955161213874817
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9943425059318542
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9991124272346497
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9967240691184998
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9974883794784546
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9994983077049255
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9978383779525757
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.997186541557312
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.999626874923706
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9974728226661682
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9973822236061096
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9994543194770813
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9979308247566223
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9976049065589905
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9995967745780945
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.9972719550132751
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9966524243354797
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9994775056838989
#   label: "Right"
# }
# , classification {
#   index: 1
#   score: 0.997259259223938
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9969388842582703
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9950261116027832
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9944008588790894
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9938939809799194
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9937537908554077
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.993075430393219
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9914703369140625
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.9935998916625977
#   label: "Right"
# }
# ]
# [classification {
#   index: 1
#   score: 0.